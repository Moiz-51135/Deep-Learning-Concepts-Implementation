# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %% [markdown]
# # Using Pretrained Weights

# %%
model=ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 [==============================] - 3s 0us/step

# %%
image_pth1='/kaggle/input/dogandcat/cat.jpeg'
img= image.load_img(image_pth1,target_size=(224,224))
x = image.img_to_array(img)
x=np.expand_dims(x,axis=0)
x=preprocess_input(x)

# %% [markdown]
# # Predicting Cat

# %%
predictions=model.predict(x)
print('predicted',decode_predictions(predictions,top=3)[0])
# Out:
# ...
# 35363/35363 [==============================] - 0s 0us/step
# predicted [('n02124075', 'Egyptian_cat', 0.9126113), ('n02123045', 'tabby', 0.05978921), ('n02123159', 'tiger_cat', 0.010471495)]

# %%
image_pth2='/kaggle/input/dogandcat/download.jpeg'
img2= image.load_img(image_pth2,target_size=(224,224))
y = image.img_to_array(img2)
y=np.expand_dims(y,axis=0)
y=preprocess_input(y)

# %% [markdown]
# # Predicting Dog

# %%
predictions_2=model.predict(y)
print('predicted',decode_predictions(predictions_2,top=3)[0])
# Out:
# 1/1 [==============================] - 0s 135ms/step
# predicted [('n02099601', 'golden_retriever', 0.98656356), ('n02099712', 'Labrador_retriever', 0.012782834), ('n02104029', 'kuvasz', 0.0003238907)]
